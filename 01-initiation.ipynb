# %%
a = 3
print(a)
# Out:
# 3

# %%
a = 4
print(a)
# Out:
# 4

# %%
b = 5
print(b)
# Out:
# 5

# %%
c = a + b
print(c)
# Out:
# 9

# %% [markdown]
# # Ceci est un notebook Jupyter
# ## Je teste le markdown
